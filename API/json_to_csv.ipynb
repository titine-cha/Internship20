# %% [markdown]
# # Run ----->

# %%
# Script adapted for MVM data (API GetSamplesBySite)
# Convert the JSON files to csv by flattening th nested data
# Adapted from https://saralgyaan.com/posts/convert-json-to-csv-using-python/
# Authorship Fantine Chabernaud

import csv
import json
import pandas as pd
import os

import datetime


def get_list_of_json_files():
    #Read the folder where the JSON files are stored and returns a list of the files' names
    list_of_files = os.listdir('data_to_convert_input')
    return list_of_files


def create_list_from_json(jsonfile):
    print('Opening file ' , datetime.datetime.now().time())
    with open(jsonfile, 'r', encoding='utf-8') as f:
        data = json.load(f)     
    df = pd.json_normalize(data)
    
    # Columns to drop 
    columns_to_drop = ['CreateDate','DeliveryMethodTypeCode','DeliveryName','EditDate','HasSampleComment','LocationX', 
    'LocationY','MaxDepth','MinDepth','NumSubSamples','IsBiologicalSample','ProductCode','RelativeLocationType',
    'SampleAccredited','SampleAnalysisLab','SampleAnalysisMethod','SampleCommentFirst100','SampleIsSensitive',
    'SampleMediumTypeName','SampleStatus','SamplingMethod','SamplingMethodStandard','SamplingMethodTypeCode',
    'SourceSampleId','StudyName','SubProgramName','SurveyType','UserIsAuthorized','SiteMetadata',
    'SampleMetadataList','TaxonGroupCalculationValues','SampleCoordinate','SampleCoordinateSRS',
    'ObservedPropertyList','SampleLocationWkt','SiteCoordinate','IndexValues','ObservationValues']
    df.drop(columns = columns_to_drop, inplace = True)
    
    #Flatten the nested data
    clean_df = flatten(data,df)
    return clean_df


def flatten(data,df):
    print('Flattening nested data - START ', datetime.datetime.now().time())
    nested_header_list = ['IndexValues','ObservationValues']
    header_list = ['IndexFlagCodes','ProductName','SampleDate','SampleId',
                    'SiteEUId','SiteId','SiteName','SiteType','WaterZone']
    nested_columns_to_drop = ['IndexValues_Id','IndexValues_FomaIndexName',
       'IndexValues_FomaIndexShortName', 'IndexValues_FomaIndexVersionId',
       'IndexValues_IndexVersion', 'IndexValues_InputValuesText',
       'IndexValues_ObservationSetId', 'IndexValues_UnitOfMeasureName',
       'IndexValues_VisibleInUI',
       'ObservationValues_AccessRestriction', 'ObservationValues_AnalysisDate',
       'ObservationValues_AnalysisLab', 'ObservationValues_AnalysisMethod',
       'ObservationValues_DefaultUnitName', 'ObservationValues_DefaultValue',
       'ObservationValues_IsAccredited', 'ObservationValues_IsComplexType',
       'ObservationValues_IsQualitative', 'ObservationValues_ObservationSetId',
       'ObservationValues_ObservedPropertyId',
       'ObservationValues_PropertyAbbrevName',
       'ObservationValues_PropertyAuthorityCode',
       'ObservationValues_PropertyCode', 
       'ObservationValues_QualityCode', 'ObservationValues_ReportedValue',
       'ObservationValues_TaxonSwedishName',
       'ObservationValues_UnitOfMeasureId',
       'ObservationValues_UnitOfMeasureName',
       'ObservationValues_ValueRepresentationTypeName']
    # Are kept only 'ObservationValues_PropertyName' and 'IndexValues_Value'

    # Flatten the nested columns and merge with data 
    for nested_header in nested_header_list:
        my_data = pd.json_normalize(data=data, record_path=nested_header,record_prefix=nested_header+'_', meta=header_list)
        df = df.merge(my_data, how='outer') 
            
    #Create a new df with only vattenkemi rows
    is_vnk = df['ProductName']=='Vattenkemi'
    df_vnk = df[is_vnk]
    print(df_vnk.shape)
        
    #Dropping useless columns
    df_vnk.drop(columns=nested_columns_to_drop, inplace=False, errors='ignore')
    
    # Final result
    print('Flattening nested data - END ', datetime.datetime.now().time())
    return df_vnk   

    
def write_csv():
    list_of_files = get_list_of_json_files()
    #Iteratively open each JSON file to process it and aggregate it to the CSV file in output
    for file in list_of_files:
        print(file)
        if file == list_of_files[0]:
            df = create_list_from_json(f'data_to_convert_input/{file}')  # create the row to be added to csv for each file (json-file)
            print('Printing output')
            df.to_csv('converted_output/json_to_csv_auto_OUTPUT.csv', index=False, mode='w', header=True)
            
        else :
            df = create_list_from_json(f'data_to_convert_input/{file}')  # create the row to be added to csv for each file (json-file)
            print('Printing output')
            df.to_csv('converted_output/json_to_csv_auto_OUTPUT.csv', index=False, mode='a', header=False)
  
    print('Script end ', datetime.datetime.now().time())

        
if __name__=="__main__":
    write_csv()
# Out:
# mvm_dataset_site_101.json
# Opening file  17:58:50.813381
# Flattening nested data - START  17:58:51.896395
# (5263, 40)
# Flattening nested data - END  17:58:52.814326
# Printing output
# mvm_dataset_site_1082.json
# Opening file  17:58:52.981131
# Flattening nested data - START  17:58:53.153489
# (2417, 30)
# Flattening nested data - END  17:58:53.291760
# Printing output
# mvm_dataset_site_109.json
# Opening file  17:58:53.323727
# Flattening nested data - START  17:58:54.189821
# (6550, 40)
# Flattening nested data - END  17:58:54.968371
# Printing output
# mvm_dataset_site_112.json
# Opening file  17:58:55.091301
# Flattening nested data - START  17:58:55.628151
# (3390, 40)
# Flattening nested data - END  17:58:56.030574
# Printing output
# mvm_dataset_site_114.json
# Opening file  17:58:56.096536
# Flattening nested data - START  17:58:56.571463
# (3204, 40)
# Flattening nested data - END  17:58:57.029205
# Printing output
# mvm_dataset_site_116.json
# Opening file  17:58:57.087171
# Flattening nested data - START  17:58:57.525785
# (3151, 40)
# Flattening nested data - END  17:58:57.917542
# Printing output
# mvm_dataset_site_118.json
# Opening file  17:58:57.978505
# Flattening nested data - START  17:59:00.112975
# (15440, 40)
# Flattening nested data - END  17:59:01.795003
# Printing output
# mvm_dataset_site_119.json
# Opening file  17:59:02.067847
# Flattening nested data - START  17:59:02.578336
# (3623, 40)
# Flattening nested data - END  17:59:03.123020
# Printing output
# mvm_dataset_site_1319.json
# Opening file  17:59:03.202428
# Flattening nested data - START  17:59:03.269566
# (70, 30)
# Flattening nested data - END  17:59:03.297510
# Printing output
# mvm_dataset_site_132.json
# Opening file  17:59:03.301507
# Flattening nested data - START  17:59:05.123260
# (17107, 40)
# Flattening nested data - END  17:59:06.734330
# Printing output
# mvm_dataset_site_136.json
# Opening file  17:59:07.036822
# Flattening nested data - START  17:59:08.139741
# (10512, 40)
# Flattening nested data - END  17:59:08.991252
# Printing output
# mvm_dataset_site_137.json
# Opening file  17:59:09.167128
# Flattening nested data - START  17:59:09.902855
# (6189, 40)
# Flattening nested data - END  17:59:10.500509
# Printing output
# mvm_dataset_site_138.json
# Opening file  17:59:10.625993
# Flattening nested data - START  17:59:11.151851
# (4262, 40)
# Flattening nested data - END  17:59:11.633602
# Printing output
# mvm_dataset_site_1395.json
# Opening file  17:59:11.708558
# Flattening nested data - START  17:59:11.760564
# (41, 30)
# Flattening nested data - END  17:59:11.787547
# Printing output
# mvm_dataset_site_1397.json
# Opening file  17:59:11.793546
# Flattening nested data - START  17:59:11.823510
# (41, 30)
# Flattening nested data - END  17:59:11.894468
# Printing output
# mvm_dataset_site_140.json
# Opening file  17:59:11.898466
# Flattening nested data - START  17:59:12.665023
# (2851, 40)
# Flattening nested data - END  17:59:13.401599
# Printing output
# mvm_dataset_site_1405.json
# Opening file  17:59:13.470561
# Flattening nested data - START  17:59:13.488548
# (41, 30)
# Flattening nested data - END  17:59:13.535524
# Printing output
# mvm_dataset_site_144.json
# Opening file  17:59:13.541519
# Flattening nested data - START  17:59:14.078208
# (2763, 40)
# Flattening nested data - END  17:59:14.574923
# Printing output
# mvm_dataset_site_146.json
# Opening file  17:59:14.640884
# Flattening nested data - START  17:59:15.244538
# (2883, 40)
# Flattening nested data - END  17:59:15.802215
# Printing output
# mvm_dataset_site_1476.json
# Opening file  17:59:15.871176
# Flattening nested data - START  17:59:15.919149
# (21, 30)
# Flattening nested data - END  17:59:15.955128
# Printing output
# mvm_dataset_site_1484.json
# Opening file  17:59:15.964123
# Flattening nested data - START  17:59:15.970119
# (21, 30)
# Flattening nested data - END  17:59:16.009099
# Printing output
# mvm_dataset_site_1488.json
# Opening file  17:59:16.013094
# Flattening nested data - START  17:59:16.025086
# (21, 30)
# Flattening nested data - END  17:59:16.062064
# Printing output
# mvm_dataset_site_150.json
# Opening file  17:59:16.066062
# Flattening nested data - START  17:59:16.359893
# (1891, 40)
# Flattening nested data - END  17:59:16.652724
# Printing output
# mvm_dataset_site_151.json
# Opening file  17:59:16.690701
# Flattening nested data - START  17:59:17.114459
# (2480, 40)
# Flattening nested data - END  17:59:17.449268
# Printing output
# mvm_dataset_site_152.json
# Opening file  17:59:17.503235
# Flattening nested data - START  17:59:17.893008
# (2496, 40)
# Flattening nested data - END  17:59:18.237811
# Printing output
# mvm_dataset_site_155.json
# Opening file  17:59:18.299773
# Flattening nested data - START  17:59:18.628266
# (1840, 40)
# Flattening nested data - END  17:59:18.850870
# Printing output
# mvm_dataset_site_1596.json
# Opening file  17:59:18.894831
# Flattening nested data - START  17:59:18.938473
# (20, 30)
# Flattening nested data - END  17:59:18.968456
# Printing output
# mvm_dataset_site_1684.json
# Opening file  17:59:18.973451
# Flattening nested data - START  17:59:19.249061
# (1694, 40)
# Flattening nested data - END  17:59:19.436932
# Printing output
# mvm_dataset_site_1755.json
# Opening file  17:59:19.479908
# Flattening nested data - START  17:59:19.523264
# (22, 30)
# Flattening nested data - END  17:59:19.555246
# Printing output
# mvm_dataset_site_18950.json
# Opening file  17:59:19.559263
# Flattening nested data - START  17:59:19.647025
# (286, 40)
# Flattening nested data - END  17:59:19.734974
# Printing output
# mvm_dataset_site_1960.json
# Opening file  17:59:19.742969
# Flattening nested data - START  17:59:21.262788
# (13925, 40)
# Flattening nested data - END  17:59:22.477087
# Printing output
# mvm_dataset_site_2029.json
# Opening file  17:59:22.726943
# Flattening nested data - START  17:59:22.776563
# (51, 30)
# Flattening nested data - END  17:59:22.804547
# Printing output
# mvm_dataset_site_22501.json
# Opening file  17:59:22.812053
# Flattening nested data - START  17:59:22.852685
# (0, 40)
# Flattening nested data - END  17:59:22.887665
# Printing output
# mvm_dataset_site_23857.json
# Opening file  17:59:22.889664
# Flattening nested data - START  17:59:22.901655
# (172, 30)
# Flattening nested data - END  17:59:22.933642
# Printing output
# mvm_dataset_site_24185.json
# Opening file  17:59:22.939635
# Flattening nested data - START  17:59:22.962621
# (105, 30)
# Flattening nested data - END  17:59:22.999601
# Printing output
# mvm_dataset_site_24222.json
# Opening file  17:59:23.003618
# Flattening nested data - START  17:59:23.013226
# (86, 30)
# Flattening nested data - END  17:59:23.043192
# Printing output
# mvm_dataset_site_24305.json
# Opening file  17:59:23.046208
# Flattening nested data - START  17:59:23.067590
# (105, 30)
# Flattening nested data - END  17:59:23.099569
# Printing output
# mvm_dataset_site_24315.json
# Opening file  17:59:23.103585
# Flattening nested data - START  17:59:23.112580
# (95, 30)
# Flattening nested data - END  17:59:23.145545
# Printing output
# mvm_dataset_site_24320.json
# Opening file  17:59:23.154556
# Flattening nested data - START  17:59:23.174527
# (86, 30)
# Flattening nested data - END  17:59:23.210507
# Printing output
# mvm_dataset_site_24372.json
# Opening file  17:59:23.215505
# Flattening nested data - START  17:59:23.222500
# (17, 30)
# Flattening nested data - END  17:59:23.248482
# Printing output
# mvm_dataset_site_24384.json
# Opening file  17:59:23.251500
# Flattening nested data - START  17:59:23.260601
# (95, 30)
# Flattening nested data - END  17:59:23.289583
# Printing output
# mvm_dataset_site_24391.json
# Opening file  17:59:23.293581
# Flattening nested data - START  17:59:23.302699
# (105, 30)
# Flattening nested data - END  17:59:23.332665
# Printing output
# mvm_dataset_site_24421.json
# Opening file  17:59:23.337661
# Flattening nested data - START  17:59:23.348656
# (17, 30)
# Flattening nested data - END  17:59:23.379638
# Printing output
# mvm_dataset_site_24429.json
# Opening file  17:59:23.382637
# Flattening nested data - START  17:59:23.388232
# (17, 30)
# Flattening nested data - END  17:59:23.414217
# Printing output
# mvm_dataset_site_24438.json
# Opening file  17:59:23.417216
# Flattening nested data - START  17:59:23.426210
# (86, 30)
# Flattening nested data - END  17:59:23.459173
# Printing output
# mvm_dataset_site_24447.json
# Opening file  17:59:23.466168
# Flattening nested data - START  17:59:23.478180
# (122, 30)
# Flattening nested data - END  17:59:23.509146
# Printing output
# mvm_dataset_site_24457.json
# Opening file  17:59:23.514142
# Flattening nested data - START  17:59:23.520155
# (17, 30)
# Flattening nested data - END  17:59:23.547124
# Printing output
# mvm_dataset_site_24489.json
# Opening file  17:59:23.550121
# Flattening nested data - START  17:59:23.570111
# (105, 30)
# Flattening nested data - END  17:59:23.605107
# Printing output
# mvm_dataset_site_24548.json
# Opening file  17:59:23.609105
# Flattening nested data - START  17:59:23.615101
# (17, 30)
# Flattening nested data - END  17:59:23.640087
# Printing output
# mvm_dataset_site_24608.json
# Opening file  17:59:23.643086
# Flattening nested data - START  17:59:23.652082
# (105, 30)
# Flattening nested data - END  17:59:23.688044
# Printing output
# mvm_dataset_site_2469.json
# Opening file  17:59:23.693041
# Flattening nested data - START  17:59:23.766188
# (472, 30)
# Flattening nested data - END  17:59:23.820158
# Printing output
# mvm_dataset_site_24762.json
# Opening file  17:59:23.828153
# Flattening nested data - START  17:59:23.852124
# (167, 30)
# Flattening nested data - END  17:59:23.884110
# Printing output
# mvm_dataset_site_24850.json
# Opening file  17:59:23.889120
# Flattening nested data - START  17:59:23.899114
# (97, 30)
# Flattening nested data - END  17:59:23.935078
# Printing output
# mvm_dataset_site_24901.json
# Opening file  17:59:23.939081
# Flattening nested data - START  17:59:23.957503
# (108, 30)
# Flattening nested data - END  17:59:23.994465
# Printing output
# mvm_dataset_site_24923.json
# Opening file  17:59:23.999461
# Flattening nested data - START  17:59:24.007457
# (17, 30)
# Flattening nested data - END  17:59:24.035440
# Printing output
# mvm_dataset_site_24935.json
# Opening file  17:59:24.038438
# Flattening nested data - START  17:59:24.044434
# (17, 30)
# Flattening nested data - END  17:59:24.069420
# Printing output
# mvm_dataset_site_25181.json
# Opening file  17:59:24.072418
# Flattening nested data - START  17:59:24.091984
# (27, 30)
# Flattening nested data - END  17:59:24.118969
# Printing output
# mvm_dataset_site_25235.json
# Opening file  17:59:24.121948
# Flattening nested data - START  17:59:24.127963
# (17, 30)
# Flattening nested data - END  17:59:24.161929
# Printing output
# mvm_dataset_site_25338.json
# Opening file  17:59:24.165926
# Flattening nested data - START  17:59:24.188473
# (46, 30)
# Flattening nested data - END  17:59:24.221438
# Printing output
# mvm_dataset_site_25451.json
# Opening file  17:59:24.227432
# Flattening nested data - START  17:59:24.235429
# (17, 30)
# Flattening nested data - END  17:59:24.260432
# Printing output
# mvm_dataset_site_25533.json
# Opening file  17:59:24.265411
# Flattening nested data - START  17:59:24.285417
# (105, 30)
# Flattening nested data - END  17:59:24.319398
# Printing output
# mvm_dataset_site_2621.json
# Opening file  17:59:24.325358
# Flattening nested data - START  17:59:24.339563
# (22, 30)
# Flattening nested data - END  17:59:24.367531
# Printing output
# mvm_dataset_site_2687.json
# Opening file  17:59:24.372527
# Flattening nested data - START  17:59:24.406506
# (333, 30)
# Flattening nested data - END  17:59:24.459478
# Printing output
# mvm_dataset_site_27213.json
# Opening file  17:59:24.465473
# Flattening nested data - START  17:59:24.505767
# (69, 30)
# Flattening nested data - END  17:59:24.535750
# Printing output
# mvm_dataset_site_27232.json
# Opening file  17:59:24.539731
# Flattening nested data - START  17:59:24.550689
# (37, 30)
# Flattening nested data - END  17:59:24.576674
# Printing output
# mvm_dataset_site_27263.json
# Opening file  17:59:24.580655
# Flattening nested data - START  17:59:24.589667
# (101, 30)
# Flattening nested data - END  17:59:24.621633
# Printing output
# mvm_dataset_site_2731.json
# Opening file  17:59:24.626647
# Flattening nested data - START  17:59:24.643636
# (45, 30)
# Flattening nested data - END  17:59:24.671621
# Printing output
# mvm_dataset_site_27389.json
# Opening file  17:59:24.676614
# Flattening nested data - START  17:59:24.684612
# (69, 30)
# Flattening nested data - END  17:59:24.711580
# Printing output
# mvm_dataset_site_27453.json
# Opening file  17:59:24.715579
# Flattening nested data - START  17:59:24.733589
# (69, 30)
# Flattening nested data - END  17:59:24.765553
# Printing output
# mvm_dataset_site_27655.json
# Opening file  17:59:24.770551
# Flattening nested data - START  17:59:24.778563
# (69, 30)
# Flattening nested data - END  17:59:24.807546
# Printing output
# mvm_dataset_site_2766.json
# Opening file  17:59:24.812526
# Flattening nested data - START  17:59:24.830518
# (132, 30)
# Flattening nested data - END  17:59:24.869495
# Printing output
# mvm_dataset_site_27666.json
# Opening file  17:59:24.873510
# Flattening nested data - START  17:59:24.881503
# (69, 30)
# Flattening nested data - END  17:59:24.910469
# Printing output
# mvm_dataset_site_28075.json
# Opening file  17:59:24.914467
# Flattening nested data - START  17:59:24.934473
# (232, 40)
# Flattening nested data - END  17:59:24.978448
# Printing output
# mvm_dataset_site_28143.json
# Opening file  17:59:24.985426
# Flattening nested data - START  17:59:24.993058
# (69, 30)
# Flattening nested data - END  17:59:25.033016
# Printing output
# mvm_dataset_site_28153.json
# Opening file  17:59:25.038014
# Flattening nested data - START  17:59:25.047026
# (69, 30)
# Flattening nested data - END  17:59:25.083988
# Printing output
# mvm_dataset_site_28485.json
# Opening file  17:59:25.087985
# Flattening nested data - START  17:59:25.096980
# (69, 30)
# Flattening nested data - END  17:59:25.125963
# Printing output
# mvm_dataset_site_28607.json
# Opening file  17:59:25.128961
# Flattening nested data - START  17:59:25.136956
# (69, 30)
# Flattening nested data - END  17:59:25.164941
# Printing output
# mvm_dataset_site_28619.json
# Opening file  17:59:25.168938
# Flattening nested data - START  17:59:25.177006
# (69, 30)
# Flattening nested data - END  17:59:25.211969
# Printing output
# mvm_dataset_site_28630.json
# Opening file  17:59:25.215967
# Flattening nested data - START  17:59:25.228959
# (68, 30)
# Flattening nested data - END  17:59:25.257941
# Printing output
# mvm_dataset_site_28680.json
# Opening file  17:59:25.262939
# Flattening nested data - START  17:59:25.278929
# (69, 40)
# Flattening nested data - END  17:59:25.318907
# Printing output
# mvm_dataset_site_28730.json
# Opening file  17:59:25.323904
# Flattening nested data - START  17:59:25.392637
# (223, 30)
# Flattening nested data - END  17:59:25.427619
# Printing output
# mvm_dataset_site_28768.json
# Opening file  17:59:25.436612
# Flattening nested data - START  17:59:25.468636
# (69, 30)
# Flattening nested data - END  17:59:25.497602
# Printing output
# mvm_dataset_site_28905.json
# Opening file  17:59:25.501612
# Flattening nested data - START  17:59:25.509613
# (69, 30)
# Flattening nested data - END  17:59:25.543576
# Printing output
# mvm_dataset_site_3087.json
# Opening file  17:59:25.548576
# Flattening nested data - START  17:59:25.689559
# (823, 40)
# Flattening nested data - END  17:59:25.847467
# Printing output
# mvm_dataset_site_3125.json
# Opening file  17:59:25.864474
# Flattening nested data - START  17:59:25.872451
# (0, 40)
# Flattening nested data - END  17:59:25.913446
# Printing output
# mvm_dataset_site_3135.json
# Opening file  17:59:25.916163
# Flattening nested data - START  17:59:25.975651
# (0, 40)
# Flattening nested data - END  17:59:26.004617
# Printing output
# mvm_dataset_site_3137.json
# Opening file  17:59:26.007617
# Flattening nested data - START  17:59:26.014614
# (0, 40)
# Flattening nested data - END  17:59:26.045611
# Printing output
# mvm_dataset_site_3194.json
# Opening file  17:59:26.048592
# Flattening nested data - START  17:59:26.054192
# (0, 40)
# Flattening nested data - END  17:59:26.085157
# Printing output
# mvm_dataset_site_3250.json
# Opening file  17:59:26.087155
# Flattening nested data - START  17:59:26.100148
# (0, 40)
# Flattening nested data - END  17:59:26.134128
# Printing output
# mvm_dataset_site_3276.json
# Opening file  17:59:26.136145
# Flattening nested data - START  17:59:26.142208
# (0, 40)
# Flattening nested data - END  17:59:26.173174
# Printing output
# mvm_dataset_site_3290.json
# Opening file  17:59:26.175190
# Flattening nested data - START  17:59:26.181662
# (0, 40)
# Flattening nested data - END  17:59:26.211628
# Printing output
# mvm_dataset_site_35360.json
# Opening file  17:59:26.213626
# Flattening nested data - START  17:59:26.286690
# (74, 30)
# Flattening nested data - END  17:59:26.318653
# Printing output
# mvm_dataset_site_35479.json
# Opening file  17:59:26.323650
# Flattening nested data - START  17:59:26.336645
# (37, 30)
# Flattening nested data - END  17:59:26.364629
# Printing output
# mvm_dataset_site_35516.json
# Opening file  17:59:26.367640
# Flattening nested data - START  17:59:26.375056
# (37, 30)
# Flattening nested data - END  17:59:26.401021
# Printing output
# mvm_dataset_site_35539.json
# Opening file  17:59:26.404019
# Flattening nested data - START  17:59:26.413032
# (69, 30)
# Flattening nested data - END  17:59:26.438998
# Printing output
# mvm_dataset_site_35911.json
# Opening file  17:59:26.443017
# Flattening nested data - START  17:59:26.456063
# (37, 30)
# Flattening nested data - END  17:59:26.490025
# Printing output
# mvm_dataset_site_35990.json
# Opening file  17:59:26.494043
# Flattening nested data - START  17:59:26.503019
# (37, 30)
# Flattening nested data - END  17:59:26.529004
# Printing output
# mvm_dataset_site_36006.json
# Opening file  17:59:26.552989
# Flattening nested data - START  17:59:26.577073
# (37, 30)
# Flattening nested data - END  17:59:26.605040
# Printing output
# mvm_dataset_site_3630.json
# Opening file  17:59:26.608047
# Flattening nested data - START  17:59:26.641612
# (0, 40)
# Flattening nested data - END  17:59:26.680591
# Printing output
# mvm_dataset_site_38989.json
# Opening file  17:59:26.683702
# Flattening nested data - START  17:59:26.696610
# (32, 30)
# Flattening nested data - END  17:59:26.730591
# Printing output
# mvm_dataset_site_39019.json
# Opening file  17:59:26.735588
# Flattening nested data - START  17:59:26.754578
# (96, 30)
# Flattening nested data - END  17:59:26.794553
# Printing output
# mvm_dataset_site_39093.json
# Opening file  17:59:26.799550
# Flattening nested data - START  17:59:26.806567
# (31, 30)
# Flattening nested data - END  17:59:26.833551
# Printing output
# mvm_dataset_site_39143.json
# Opening file  17:59:26.836549
# Flattening nested data - START  17:59:26.865593
# (31, 30)
# Flattening nested data - END  17:59:26.892562
# Printing output
# mvm_dataset_site_39167.json
# Opening file  17:59:26.895560
# Flattening nested data - START  17:59:26.901573
# (31, 30)
# Flattening nested data - END  17:59:26.927558
# Printing output
# mvm_dataset_site_39375.json
# Opening file  17:59:26.932537
# Flattening nested data - START  17:59:26.947530
# (31, 30)
# Flattening nested data - END  17:59:26.982526
# Printing output
# mvm_dataset_site_39403.json
# Opening file  17:59:26.985525
# Flattening nested data - START  17:59:26.995908
# (111, 30)
# Flattening nested data - END  17:59:27.032871
# Printing output
# mvm_dataset_site_39580.json
# Opening file  17:59:27.036886
# Flattening nested data - START  17:59:27.043881
# (32, 30)
# Flattening nested data - END  17:59:27.070847
# Printing output
# mvm_dataset_site_39637.json
# Opening file  17:59:27.073845
# Flattening nested data - START  17:59:27.080860
# (32, 30)
# Flattening nested data - END  17:59:27.107844
# Printing output
# mvm_dataset_site_39733.json
# Opening file  17:59:27.111826
# Flattening nested data - START  17:59:27.117838
# (32, 30)
# Flattening nested data - END  17:59:27.150802
# Printing output
# mvm_dataset_site_39757.json
# Opening file  17:59:27.154799
# Flattening nested data - START  17:59:27.163811
# (69, 30)
# Flattening nested data - END  17:59:27.201771
# Printing output
# mvm_dataset_site_40061.json
# Opening file  17:59:27.205769
# Flattening nested data - START  17:59:27.218781
# (149, 30)
# Flattening nested data - END  17:59:27.250744
# Printing output
# mvm_dataset_site_40292.json
# Opening file  17:59:27.254759
# Flattening nested data - START  17:59:27.263735
# (32, 30)
# Flattening nested data - END  17:59:27.292737
# Printing output
# mvm_dataset_site_40469.json
# Opening file  17:59:27.295737
# Flattening nested data - START  17:59:27.303713
# (69, 30)
# Flattening nested data - END  17:59:27.331699
# Printing output
# mvm_dataset_site_40470.json
# Opening file  17:59:27.337711
# Flattening nested data - START  17:59:27.348686
# (69, 30)
# Flattening nested data - END  17:59:27.380686
# Printing output
# mvm_dataset_site_40754.json
# Opening file  17:59:27.383686
# Flattening nested data - START  17:59:27.391947
# (72, 30)
# Flattening nested data - END  17:59:27.425911
# Printing output
# mvm_dataset_site_4088.json
# Opening file  17:59:27.429908
# Flattening nested data - START  17:59:27.535816
# (0, 40)
# Flattening nested data - END  17:59:27.587786
# Printing output
# mvm_dataset_site_41084.json
# Opening file  17:59:27.595083
# Flattening nested data - START  17:59:27.615859
# (72, 30)
# Flattening nested data - END  17:59:27.647822
# Printing output
# mvm_dataset_site_41115.json
# Opening file  17:59:27.652820
# Flattening nested data - START  17:59:27.662832
# (72, 30)
# Flattening nested data - END  17:59:27.692797
# Printing output
# mvm_dataset_site_41145.json
# Opening file  17:59:27.695813
# Flattening nested data - START  17:59:27.701809
# (35, 30)
# Flattening nested data - END  17:59:27.727794
# Printing output
# mvm_dataset_site_41261.json
# Opening file  17:59:27.729794
# Flattening nested data - START  17:59:27.774839
# (72, 30)
# Flattening nested data - END  17:59:27.817798
# Printing output
# mvm_dataset_site_41322.json
# Opening file  17:59:27.821795
# Flattening nested data - START  17:59:27.846779
# (72, 30)
# Flattening nested data - END  17:59:27.898752
# Printing output
# mvm_dataset_site_41550.json
# Opening file  17:59:27.903749
# Flattening nested data - START  17:59:27.915739
# (37, 30)
# Flattening nested data - END  17:59:27.941725
# Printing output
# mvm_dataset_site_41745.json
# Opening file  17:59:27.945723
# Flattening nested data - START  17:59:27.951483
# (37, 30)
# Flattening nested data - END  17:59:27.978471
# Printing output
# mvm_dataset_site_43160.json
# Opening file  17:59:27.982467
# Flattening nested data - START  17:59:28.013467
# (7, 30)
# Flattening nested data - END  17:59:28.041434
# Printing output
# mvm_dataset_site_43174.json
# Opening file  17:59:28.044432
# Flattening nested data - START  17:59:28.050069
# (7, 30)
# Flattening nested data - END  17:59:28.077035
# Printing output
# mvm_dataset_site_43253.json
# Opening file  17:59:28.079033
# Flattening nested data - START  17:59:28.085049
# (7, 30)
# Flattening nested data - END  17:59:28.110035
# Printing output
# mvm_dataset_site_43272.json
# Opening file  17:59:28.113016
# Flattening nested data - START  17:59:28.119011
# (7, 30)
# Flattening nested data - END  17:59:28.147014
# Printing output
# mvm_dataset_site_43290.json
# Opening file  17:59:28.149995
# Flattening nested data - START  17:59:28.161668
# (7, 30)
# Flattening nested data - END  17:59:28.186636
# Printing output
# mvm_dataset_site_43302.json
# Opening file  17:59:28.198637
# Flattening nested data - START  17:59:28.224010
# (7, 30)
# Flattening nested data - END  17:59:28.250994
# Printing output
# mvm_dataset_site_43317.json
# Opening file  17:59:28.253992
# Flattening nested data - START  17:59:28.263987
# (7, 30)
# Flattening nested data - END  17:59:28.291971
# Printing output
# mvm_dataset_site_43363.json
# Opening file  17:59:28.294969
# Flattening nested data - START  17:59:28.300967
# (7, 30)
# Flattening nested data - END  17:59:28.325951
# Printing output
# mvm_dataset_site_43364.json
# Opening file  17:59:28.328948
# Flattening nested data - START  17:59:28.342850
# (7, 30)
# Flattening nested data - END  17:59:28.373832
# Printing output
# mvm_dataset_site_43390.json
# Opening file  17:59:28.377831
# Flattening nested data - START  17:59:28.384828
# (7, 30)
# Flattening nested data - END  17:59:28.420808
# Printing output
# mvm_dataset_site_43430.json
# Opening file  17:59:28.422823
# Flattening nested data - START  17:59:28.445896
# (7, 30)
# Flattening nested data - END  17:59:28.473881
# Printing output
# mvm_dataset_site_43512.json
# Opening file  17:59:28.476879
# Flattening nested data - START  17:59:28.493948
# (7, 30)
# Flattening nested data - END  17:59:28.517934
# Printing output
# mvm_dataset_site_43561.json
# Opening file  17:59:28.521940
# Flattening nested data - START  17:59:28.542957
# (7, 30)
# Flattening nested data - END  17:59:28.568923
# Printing output
# mvm_dataset_site_43564.json
# Opening file  17:59:28.572920
# Flattening nested data - START  17:59:28.583915
# (7, 30)
# Flattening nested data - END  17:59:28.621891
# Printing output
# mvm_dataset_site_43580.json
# Opening file  17:59:28.624890
# Flattening nested data - START  17:59:28.630886
# (7, 30)
# Flattening nested data - END  17:59:28.654873
# Printing output
# mvm_dataset_site_43610.json
# Opening file  17:59:28.659869
# Flattening nested data - START  17:59:28.665095
# (7, 30)
# Flattening nested data - END  17:59:28.689100
# Printing output
# mvm_dataset_site_43689.json
# Opening file  17:59:28.692081
# Flattening nested data - START  17:59:28.697553
# (7, 30)
# Flattening nested data - END  17:59:28.722525
# Printing output
# mvm_dataset_site_43720.json
# Opening file  17:59:28.725536
# Flattening nested data - START  17:59:28.730538
# (7, 30)
# Flattening nested data - END  17:59:28.756506
# Printing output
# mvm_dataset_site_43732.json
# Opening file  17:59:28.759503
# Flattening nested data - START  17:59:28.766500
# (7, 30)
# Flattening nested data - END  17:59:28.807495
# Printing output
# mvm_dataset_site_43748.json
# Opening file  17:59:28.809493
# Flattening nested data - START  17:59:28.815474
# (7, 30)
# Flattening nested data - END  17:59:28.850452
# Printing output
# mvm_dataset_site_43786.json
# Opening file  17:59:28.855530
# Flattening nested data - START  17:59:28.862531
# (7, 30)
# Flattening nested data - END  17:59:28.887516
# Printing output
# mvm_dataset_site_43788.json
# Opening file  17:59:28.890513
# Flattening nested data - START  17:59:28.896512
# (7, 30)
# Flattening nested data - END  17:59:28.924496
# Printing output
# mvm_dataset_site_43884.json
# Opening file  17:59:28.926494
# Flattening nested data - START  17:59:28.933490
# (7, 30)
# Flattening nested data - END  17:59:28.960474
# Printing output
# mvm_dataset_site_43914.json
# Opening file  17:59:28.964474
# Flattening nested data - START  17:59:28.971472
# (7, 30)
# Flattening nested data - END  17:59:29.004449
# Printing output
# mvm_dataset_site_43917.json
# Opening file  17:59:29.007448
# Flattening nested data - START  17:59:29.013444
# (7, 30)
# Flattening nested data - END  17:59:29.040428
# Printing output
# mvm_dataset_site_43925.json
# Opening file  17:59:29.043785
# Flattening nested data - START  17:59:29.049820
# (7, 30)
# Flattening nested data - END  17:59:29.077820
# Printing output
# mvm_dataset_site_43926.json
# Opening file  17:59:29.080799
# Flattening nested data - START  17:59:29.085456
# (7, 30)
# Flattening nested data - END  17:59:29.110431
# Printing output
# mvm_dataset_site_43967.json
# Opening file  17:59:29.113421
# Flattening nested data - START  17:59:29.119432
# (7, 30)
# Flattening nested data - END  17:59:29.146421
# Printing output
# mvm_dataset_site_44026.json
# Opening file  17:59:29.150401
# Flattening nested data - START  17:59:29.196492
# (7, 30)
# Flattening nested data - END  17:59:29.224493
# Printing output
# mvm_dataset_site_44041.json
# Opening file  17:59:29.227474
# Flattening nested data - START  17:59:29.240465
# (7, 30)
# Flattening nested data - END  17:59:29.276444
# Printing output
# mvm_dataset_site_44974.json
# Opening file  17:59:29.279446
# Flattening nested data - START  17:59:29.288440
# (29, 30)
# Flattening nested data - END  17:59:29.330414
# Printing output
# mvm_dataset_site_47962.json
# Opening file  17:59:29.334412
# Flattening nested data - START  17:59:29.349403
# (0, 40)
# Flattening nested data - END  17:59:29.390378
# Printing output
# mvm_dataset_site_54.json
# Opening file  17:59:29.393377
# Flattening nested data - START  17:59:29.895092
# (3770, 40)
# Flattening nested data - END  17:59:30.442771
# Printing output
# mvm_dataset_site_5443.json
# Opening file  17:59:30.519728
# Flattening nested data - START  17:59:30.567304
# (0, 40)
# Flattening nested data - END  17:59:30.597286
# Printing output
# mvm_dataset_site_58.json
# Opening file  17:59:30.601292
# Flattening nested data - START  17:59:31.254916
# (4528, 40)
# Flattening nested data - END  17:59:31.697660
# Printing output
# mvm_dataset_site_5900.json
# Opening file  17:59:31.776616
# Flattening nested data - START  17:59:31.825042
# (0, 40)
# Flattening nested data - END  17:59:31.856025
# Printing output
# mvm_dataset_site_5997.json
# Opening file  17:59:31.860003
# Flattening nested data - START  17:59:31.878949
# (0, 40)
# Flattening nested data - END  17:59:31.923921
# Printing output
# mvm_dataset_site_60.json
# Opening file  17:59:31.925919
# Flattening nested data - START  17:59:33.687791
# (17002, 40)
# Flattening nested data - END  17:59:35.136953
# Printing output
# mvm_dataset_site_68.json
# Opening file  17:59:35.428535
# Flattening nested data - START  17:59:36.326804
# (7188, 40)
# Flattening nested data - END  17:59:37.099354
# Printing output
# mvm_dataset_site_77.json
# Opening file  17:59:37.253456
# Flattening nested data - START  17:59:38.305384
# (8747, 40)
# Flattening nested data - END  17:59:39.169889
# Printing output
# mvm_dataset_site_79.json
# Opening file  17:59:39.321797
# Flattening nested data - START  17:59:39.770473
# (4229, 40)
# Flattening nested data - END  17:59:40.172258
# Printing output
# mvm_dataset_site_82.json
# Opening file  17:59:40.248197
# Flattening nested data - START  17:59:42.215807
# (17603, 40)
# Flattening nested data - END  17:59:43.958802
# Printing output
# mvm_dataset_site_83.json
# Opening file  17:59:44.260628
# Flattening nested data - START  17:59:44.846406
# (3745, 40)
# Flattening nested data - END  17:59:45.231180
# Printing output
# mvm_dataset_site_84.json
# Opening file  17:59:45.314135
# Flattening nested data - START  17:59:47.253555
# (17611, 40)
# Flattening nested data - END  17:59:48.830647
# Printing output
# mvm_dataset_site_85.json
# Opening file  17:59:49.136469
# Flattening nested data - START  17:59:49.492449
# (4150, 40)
# Flattening nested data - END  17:59:49.814272
# Printing output
# mvm_dataset_site_88.json
# Opening file  17:59:49.886229
# Flattening nested data - START  17:59:50.907202
# (7792, 40)
# Flattening nested data - END  17:59:51.764707
# Printing output
# mvm_dataset_site_90.json
# Opening file  17:59:51.905624
# Flattening nested data - START  17:59:53.713475
# (18251, 40)
# Flattening nested data - END  17:59:55.210588
# Printing output
# mvm_dataset_site_915.json
# Opening file  17:59:55.525426
# Flattening nested data - START  17:59:55.559398
# (544, 30)
# Flattening nested data - END  17:59:55.608372
# Printing output
# mvm_dataset_site_96.json
# Opening file  17:59:55.621381
# Flattening nested data - START  17:59:57.677585
# (18410, 40)
# Flattening nested data - END  17:59:59.410591
# Printing output
# Script end  17:59:59.735399

# %% [markdown]
# # <------

# %% [markdown]
# # Draft

# %%
# Open deeply nested data 
# source https://www.kaggle.com/jboysen/quick-tutorial-flatten-nested-json-in-pandas
from datetime import datetime
import json 
import pandas as pd 

unwanted_columns = ['CreateDate','DeliveryMethodTypeCode','DeliveryName','EditDate','HasSampleComment','LocationX', 
    'LocationY','MaxDepth','MinDepth','NumSubSamples','IsBiologicalSample','ProductCode','RelativeLocationType',
    'SampleAccredited','SampleAnalysisLab','SampleAnalysisMethod','SampleCommentFirst100','SampleIsSensitive',
    'SampleMediumTypeName','SampleStatus','SamplingMethod','SamplingMethodStandard','SamplingMethodTypeCode',
    'SourceSampleId','StudyName','SubProgramName','SurveyType','UserIsAuthorized','SiteMetadata',
                      'SampleMetadataList','TaxonGroupCalculationValues','SampleCoordinate','SampleCoordinateSRS',
                      'ObservedPropertyList','SampleLocationWkt','SiteCoordinate']

def open_file():
    with open('data_to_convert_input/mvm_dataset_site_54.json', 'r', encoding='utf-8') as f:
        data = json.load(f)
    return data

def flatten():
    data = open_file()
    print(data)
    
    nested_header_list = ['IndexValues','ObservationValues'] 
    #'SiteMetadata','SampleMetadataList','TaxonGroupCalculationValues'
    
    header_list = ['IndexFlagCodes','ProductName','SampleDate','SampleId',
                    'SiteEUId','SiteId','SiteName','SiteType','WaterZone'] 
    #'CreateDate','DeliveryMethodTypeCode','DeliveryName','EditDate','HasSampleComment','LocationX', 'LocationY',
    #'MaxDepth','MinDepth','NumSubSamples','IsBiologicalSample','ProductCode',,'RelativeLocationType',
    #'SampleAccredited', 'SampleAnalysisLab','SampleAnalysisMethod','SampleCommentFirst100','SampleIsSensitive',
    #'SampleMediumTypeName', 'SampleStatus','SamplingMethod','SamplingMethodStandard','SamplingMethodTypeCode',
    #'SourceSampleId','StudyName','SubProgramName','SurveyType','UserIsAuthorized',
    
    # Create dataframe of the data 
    df = pd.json_normalize(data)
    df.drop(columns = unwanted_columns, axis=1)
    
    # Flatten the nested columns and merge with data 
    for nested_header in nested_header_list:
        my_data = pd.json_normalize(data=data, record_path=nested_header,
                                    record_prefix=nested_header+'_', meta=header_list)
        df = df.merge(my_data, how='outer')


    #Count how many rows with vattenkemi in dataframe
    #https://cmdlinetips.com/2018/02/how-to-subset-pandas-dataframe-based-on-values-of-a-column/
    #print(df['ObservationValues']['ProductName']=='Vattenkemi')
    #serie = df.apply(lambda x: True if x['ObservationValues']['ProductName']=='Vattenkemi' else False , axis=1) 
    #numOfRows = len(serie[serie == True].index)
    #print(numOfRows)
    
    #Create a new df with only vattenkemi rows
    is_vnk = df['ProductName']=='Vattenkemi'
    df_vnk = df[is_vnk]
    print(df_vnk.head(10))
    
    
    # Final result
    df_vnk.to_csv('converted_output/test.csv', index=False, mode='a', header=False)
    
if __name__=="__main__":
    flatten()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-4244feef248d> in <module>
#      68
#      69 if __name__=="__main__":
# ---> 70     flatten()
#      71
#
# <ipython-input-2-4244feef248d> in flatten()
#      26
#      27 def flatten():
# ---> 28     data = open_file()
#      29     print(data)
#      30
#
# <ipython-input-2-4244feef248d> in open_file()
#      22 def open_file():
#      23     with open('data_to_convert_input/mvm_dataset_site_54.json', 'r', encoding='utf-8') as f:
# ---> 24         data = json.load(f,object_hook=DecodeDateTime)
#      25     return data
#      26
#
# ~\Anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
# --> 296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     297
#     298
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     359     if parse_constant is not None:
#     360         kw['parse_constant'] = parse_constant
# --> 361     return cls(**kw).decode(s)
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# <ipython-input-2-4244feef248d> in DecodeDateTime(empDict)
#       9 def DecodeDateTime(empDict):
#      10     if 'CreateDate' in empDict:
# ---> 11         empDict["CreateDate"] = dateutil.parser.parse(empDict["CreateDate"])
#      12     return empDict
#      13
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1356         return parser(parserinfo).parse(timestr, **kwargs)
#    1357     else:
# -> 1358         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1359
#    1360
#
# ~\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647
#     648         if res is None:
# --> 649             raise ValueError("Unknown string format:", timestr)
#     650
#     651         if len(res) == 0:
#
# ValueError: ('Unknown string format:', '/Date(1327580646000+0100)/')

# %%
# Check content of csv file
import pandas
df = pandas.read_csv('converted_output/json_to_csv_auto_OUTPUT.csv')
df.head(2)
# Out:
#                    CreateDate  DeliveryMethodTypeCode  DeliveryName  \
# 0  /Date(1327580646000+0100)/                     NaN           NaN
# 1  /Date(1327580646000+0100)/                     NaN           NaN
#
#                      EditDate  HasSampleComment IndexFlagCodes IndexValues  \
# 0  /Date(1414686387000+0100)/             False            NaN          []
# 1  /Date(1414686387000+0100)/             False            NaN          []
#
#    IsBiologicalSample  LocationX  LocationY  ...  \
# 0               False        NaN        NaN  ...
# 1               False        NaN        NaN  ...
#
#                                         SiteMetadata   SiteName  SiteType  \
# 0  [{'Id': 5414062, 'IsInternal': False, 'Label':...  Spjutsjön       Sjö
# 1  [{'Id': 5414062, 'IsInternal': False, 'Label':...  Spjutsjön       Sjö
#
#   SourceSampleId             StudyName SubProgramName  SurveyType  \
# 0            NaN  Sjöar trendstationer            NMÖ         NaN
# 1            NaN  Sjöar trendstationer            NMÖ         NaN
#
#   TaxonGroupCalculationValues UserIsAuthorized WaterZone
# 0                          []            False       NaN
# 1                          []            False       NaN
#
# [2 rows x 42 columns]
